# %% [markdown]
# # Importamos librerías a utilizar

# %%
#Para crear y análizar redes
import networkx as nx
#Para dibujar redes y graficar funciones
import matplotlib.pyplot as plt
#Para leer desde un archivo
import pandas as pd 
import numpy as np
#Para generar errores aleatorios
import random

# %% [markdown]
# # Funciones para imprimir la informacion de la red
# ## ACTIVIDAD 1: Información general de la red
# Coloque la función imprime_informacion que se creo en anteriores prácticas. Esta función imprime la información de la red. Recibe la red G e imprime el numero de nodos, numero de enlaces, diámetro, y densidad de la red G.

# %%
def imprime_informacion(G):
    # nodos
    n = len(nx.nodes(G))
    # enlaces
    m = len(nx.edges(G))
    # diametro
    d = nx.diameter(G)
    # densidad
    densidad = nx.density(G)
    print("Informacion de la red: \n- nodos = " + str(n) +
          "\n- enlaces = " + str(m) +
          "\n- diámetro = " + str(d) +
         "\n- densidad = " + str(densidad))
    # Devuelve informacion de la red
    s = nx.info(G)
    print(s)

# %% [markdown]
# ## ACTVIDAD 2: Distribución de grados
# Coloque la función grafica_distribucion_grados que se creo en anteriores prácticas. Esta funcion grafica la distribucion de grados y en este caso no devuelve nada. Recibe la red G y la variable nombre_dg. Cálcula, imprime y gráfica la distribución de grados. La gráfica la guarda en un archivo png con nombre almacenado en la variable nombre_dg. Devuleve la distribución de grados

# %%
def grafica_distribucion_grados(G, nombre_dg):
    dist_grados = nx.degree_histogram(G)
    print(dist_grados)
    plt.title("Distribucion de Grados")
    plt.plot(dist_grados) 
    plt.xlabel("grado")
    plt.ylabel("# nodos")
    plt.savefig(nombre_dg + ".png")
    # la siguiente instruccion limpia la figura, evitando que al graficar varias figuras, estas no se encimen 
    #plt.clf()
    plt.show()
    #return dist_grados

# %% [markdown]
# # ACTIVIDAD 3: Mapa de calor por grado nodal
# Coloque la función mapa_calor_grado que se creo en anteriores prácticas. Esta función gráfica el mapa de calor de la red G. Recibe como parámetros a la red G y la variable nombre_red. Grafica el mapa de calor y lo guarda en un archivo png con el nombre alamcenado en nombre_red.

# %%
def mapa_calor_grado(G, nombre_mcalor_grado):
    degree_map = {node:nx.degree(G, node) for node in G.nodes()}
    #valores máximo y mínimos de grado
    max_degree = max(degree_map.values())
    min_degree = min(degree_map.values())
    #el grado nodal nos da el color de nodo, el cual se mapea con el mapa de color
    colores_nodos = list(degree_map.values())
    #ver mapas de color en https://matplotlib.org/stable/tutorials/colors/colormaps.html
    mapa_color = plt.get_cmap('spring')
    #dibujamos la red
    nx.draw(G, cmap=mapa_color, node_color=colores_nodos, with_labels=True)
    #dibujamos la barra de color
    sm = plt.cm.ScalarMappable(cmap=mapa_color,norm=plt.Normalize(vmin = min_degree, vmax=max_degree))
    cbar = plt.colorbar(sm)
    cbar.set_label('Grado')
    plt.savefig(nombre_mcalor_grado + ".png")
    plt.show()
    # la siguiente instruccion limpia la figura, evitando que al graficar varias figuras, estas no se encimen 
    plt.clf()

# %% [markdown]
# # Funciones para análizar la red sometida a fallos o ataques

# %% [markdown]
# ## ACTIVIDAD 4: Número de componentes conectado

# %% [markdown]
# Complete la siguiente función llamada num_componentes_conectados. Esta función recibe como parámetro la red G y devuelve el número de componentes conectados de G. Utilizar los métodos ya diseñados en python para el calculo de componentes conectados de una red, ver https://networkx.org/documentation/stable/reference/algorithms/component.html.

# %%
def num_componentes_conectados(G):
    num_cc=nx.number_connected_components(G)
    #print("Numero de componentes conectados:"+str(num_cc))
    return num_cc

# %% [markdown]
# ## ACTIVIDAD 5: Proporción del componente gigante

# %% [markdown]
# Complete la siguiente función llamada prop_componente_gigante que recibe como parámetro la red G y devuelve al proporción de nodos que tiene el componente gigante con respecto a los nodos que tiene G, este valor debe ser un número entre 0 y 1. Utilizar los métodos ya diseñados en python para el calculo de componentes conectados de una red, ver https://networkx.org/documentation/stable/reference/algorithms/component.html. Recuerde que la función len(A) le permite calcular el número de elementos en un conjunto o lista A.

# %%
def prop_componente_gigante(G):
    num_cc=num_componentes_conectados(G)
    Gcc =sorted(nx.connected_components(G), key=len, reverse=True)
    GC= G.subgraph(Gcc[0])
    n=len(nx.nodes(G))
    n_GC=len(nx.nodes(GC))
    pcg=n_GC/n
    print("La proporcion nodal entre Componente gigante y Red:"+str(pcg))
    return pcg

# %% [markdown]
# ## ACTIVIDAD 6: Graficar dos funciones en una misma figura
# Funcion que grafica dos funciones en una misma figura. Comente lo que ocurre en cada línea de código de la función
#
# Parámetros:
#
# 1) titulo : texto
#
# 2) f1_valores: lista de numeros
#
# 3) f2_valores: lista de numeros
#
# 4) f1_leyenda: texto
#
# 5) f2_leyenda: texto
#
# 6) ejex_etiqueta: texto
#
# 7) ejey_etiqueta: texto

# %%
def grafica_funciones(titulo,f1_valores, f2_valores,f1_leyenda, f2_leyenda ,ejex_etiqueta, ejey_etiqueta):
    plt.title(titulo)#se agrega un titulo a la gráfica
    plt.plot(f1_valores, label=f1_leyenda)#se ingresa la lista de valores a graficar con su respectiva etiqueta
    plt.plot(f2_valores, label=f2_leyenda)#se ingresa la lista de valores a graficar con su respectiva etiqueta
    plt.xlabel(ejex_etiqueta)#se agrega una etiqueta al eje x
    plt.ylabel(ejey_etiqueta)#se agrega una etiqueta al eje y
    plt.legend()#agrega una leyenda a la gráfica que se sobrepondrá con los nombres de las etiquetas de los valores

# %% [markdown]
# # Funciones para simular de Errores

# %% [markdown]
# ## ACTIVIDAD 7: Función para simular un error
# Complete la función error(G) que simule un error en la red G. La función recibe una red G, elimina un nodo i aleatoreamente, puede utilizar el método choice de la librería random, vea https://www.w3schools.com/python/ref_random_choice.asp. La función devuelve la nueva red G (sin el nodo i)

# %%
def error(G):
    nodos=list(G.nodes)
    nodo_atacado=random.choice(nodos)
    print("Nodo #"+str(nodo_atacado)+"fue atacado.")
    G.remove_node(nodo_atacado)
    return G

# %% [markdown]
# ## ACTIVIDAD 8: Función para simular varios errores secuenciales
# Complete la función errores_secuenciales(G,num_errores) que recibe una red G y un entero "num_errores", el cuál indica la cantidad de errores que ocurrirán en la red.
#
# La función llama secuencialmente "num_errores" veces a la función error(G). Después de cada error almacena en un la lista "num_cc_lista" el número de componentes conectados de G y en otra lista la proporción del componente gigante "prop_cg_lista". Devuleve la tupla (num_cc_lista, prop_cg_lista). Debe utilizar a las funciones creadas en las actividades 4 y 5

# %%
def errores_secuenciales(G,num_errores):
    num_cc_lista=list()
    prop_gc_lista=list()
    for i in range(num_errores):
        red_atacada=error(G)
        num_cc_lista.append(num_componentes_conectados(red_atacada))
        prop_gc_lista.append(prop_componente_gigante(red_atacada))
    return (num_cc_lista, prop_gc_lista)

# %% [markdown]
# # Funciones para simular de Ataques

# %% [markdown]
# ## ACTIVIDAD 9: Función para obtener el nodo de grado más alto de una red
# Complete la función nodo_mayor_grado(G) que recibe la red G y devuelve el nodo de mayor grado.

# %%
def nodo_mayor_grado(G):
    grados_n = [val for (node, val) in G.degree()]
    sorted(grados_n,reverse=True)
    max_grado=max(grados_n)
    print("El grado más alto de la red es: "+str(max_grado))
    tupla_grados=G.degree()
    i=0
    for i,tuple in enumerate(tupla_grados):
        elemento1=tuple[0]
        elemento2=tuple[1]
        if elemento2==max_grado:
            print("el nodo con mayor grado es el nodo #:"+str(elemento1))
            nodo_max_grado=elemento1
    return nodo_max_grado

# %% [markdown]
# ## ACTIVIDAD 10: Función para simular un ataque por grado nodal
# Complete la función ataque_grado(G) que simule un ataque por grado nodal en la red G. La función recibe una red G, elimina el nodo i de más alto grado grado y devuelve la nueva red G (sin el nodo i). Debe utilizar la función de la actividad 9

# %%
def ataque_grado(G):
    #nodos=list(G.nodes)
    nodo_atacado=nodo_mayor_grado(G)
    G.remove_node(nodo_atacado)
    return G

# %% [markdown]
# ## ACTIVIDAD 11: Función para simular varios ataques (por grado nodal) secuenciales
# Complete la función ataques_secuenciales(G,num_ataques). La función recibe una red G y un entero "num_ataques" que indica la cantidad de ataques que ocurrirán en la red. Secuencialmente llama "num_ataques" veces a la función ataque(G). Después de cada ataque almacena en una lista "num_cc_lista" el número de componentes conectados de G y en otra lista "prop_cg_lista" la proporción del componente gigante. Devuleve la tupla (num_cc_lista, prop_cg_lista).

# %%
def ataques_secuenciales(G,num_ataques):
    num_cc_lista=list()
    prop_gc_lista=list()
    for i in range(num_ataques):
        red_atacada=ataque_grado(G)
        num_cc_lista.append(num_componentes_conectados(red_atacada))
        prop_gc_lista.append(prop_componente_gigante(red_atacada))
    return (num_cc_lista, prop_gc_lista)

# %% [markdown]
# # Evaluación de redes sometidas a errores - Red de escala libre vs. red de aleatoria

# %% [markdown]
# ## ACTIVIDAD 12: Creación de una red de escala libre
# Creamos una red de escala libre Barabasi-Albert de 100 nodos y con parámetro m=5. Imprimos la información de rede

# %%
free_scale=nx.barabasi_albert_graph(100,5)
imprime_informacion(free_scale)
# Out:
# Informacion de la red:
# - nodos = 100
# - enlaces = 475
# - diámetro = 4
# - densidad = 0.09595959595959595
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 475
# Average degree:   9.5000

# %% [markdown]
# ## ACTIVIDAD 13: Creación de unaa red aleatoria
# Creamos una red aleatoria Erdos-Renyi de 100 nodos y con parámetro p=0.1. Imprimos la información de la red

# %%
aleatoria_red=nx.erdos_renyi_graph(100,0.1)
imprime_informacion(aleatoria_red)
# Out:
# Informacion de la red:
# - nodos = 100
# - enlaces = 468
# - diámetro = 4
# - densidad = 0.09454545454545454
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 468
# Average degree:   9.3600

# %% [markdown]
# ## ACTIVIDAD 14: Distribución de grados
# Llama a la función para graficar las distribucion de grados de las redes creadas y guarda ambas imagenes. Cada función llamela en una celda separada de código para que así pueda visualizar ambas figuras

# %%
grafica_distribucion_grados(free_scale,"escala_libre")
# Out:
# [0, 0, 0, 0, 1, 32, 12, 10, 8, 4, 4, 5, 1, 2, 5, 2, 3, 1, 1, 2, 2, 0, 0, 0, 0, 0, 0, 0, 1, 2, 0, 0, 2]

# %%
grafica_distribucion_grados(aleatoria_red,"red_aleatoria")
# Out:
# [0, 0, 0, 1, 2, 6, 9, 9, 7, 13, 17, 12, 12, 9, 3]

# %% [markdown]
# ## ACTIVIDAD 15: Mapas de calor por grado nodal
# Llama a la función para graficar los mapas de calor por grado nodal de las redes creadas y guarda ambas imagenes. Cada función llamela en una celda separada de código para que así pueda visualizar ambas figuras

# %%
mapa_calor_grado(free_scale,"calor_escala_libre")

# %%
mapa_calor_grado(aleatoria_red,"calor_aleatoria")

# %% [markdown]
# ## Simulación de errores secuenciales en la red de escala libre
# Utilizando la función errores_secuenciales simula 99 errores en la red de escala libre. Almacena las listas de: cantidad de componentes conectados y las proporcion del componente gigante.
#
# Note que la función errores_secuenciales recibe como paŕametro una copia de la red que se va a evaluar, esto es importante porque de otro modo se modificará la red original.

# %%
free_scale_test = free_scale.copy()
#num_cc_lista=[]
#prop_gc_lista=[]
(num_cc_lista_free_scale,prop_gc_lista_free_scale)=errores_secuenciales(free_scale_test, 99)
# Out:
# Nodo #33fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #32fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #34fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #60fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #11fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #31fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #59fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #97fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #70fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #75fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #86fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #9fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #17fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #67fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #25fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #55fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #3fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #7fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #14fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #63fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #13fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #84fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #98fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #30fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #95fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #27fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #61fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #4fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #58fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #48fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #49fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #51fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #56fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #76fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #44fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #69fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #79fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #29fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #23fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #92fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #40fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #50fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #99fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #88fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #52fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #19fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #72fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #2fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #26fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #89fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #10fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #22fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #1fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #93fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #24fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #74fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #36fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0
# Nodo #0fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9761904761904762
# Nodo #77fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.975609756097561
# Nodo #91fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.975
# Nodo #83fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9743589743589743
# Nodo #65fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9736842105263158
# Nodo #16fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9459459459459459
# Nodo #20fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9166666666666666
# Nodo #53fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9142857142857143
# Nodo #18fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9117647058823529
# Nodo #54fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9090909090909091
# Nodo #73fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.90625
# Nodo #85fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9032258064516129
# Nodo #78fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9
# Nodo #71fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9310344827586207
# Nodo #80fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9285714285714286
# Nodo #43fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9259259259259259
# Nodo #21fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.9230769230769231
# Nodo #6fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.76
# Nodo #87fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.75
# Nodo #81fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.782608695652174
# Nodo #90fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.7727272727272727
# Nodo #39fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.7619047619047619
# Nodo #57fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.65
# Nodo #28fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6842105263157895
# Nodo #46fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6111111111111112
# Nodo #8fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.5882352941176471
# Nodo #37fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.5625
# Nodo #66fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6
# Nodo #47fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.5714285714285714
# Nodo #64fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6153846153846154
# Nodo #68fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6666666666666666
# Nodo #82fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.7272727272727273
# Nodo #15fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6
# Nodo #38fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6666666666666666
# Nodo #5fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.375
# Nodo #62fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.42857142857142855
# Nodo #42fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.5
# Nodo #45fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.6
# Nodo #41fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.25
# Nodo #35fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.3333333333333333
# Nodo #12fue atacado.
# La proporcion nodal entre Componente gigante y Red:0.5
# Nodo #94fue atacado.
# La proporcion nodal entre Componente gigante y Red:1.0

# %% [markdown]
# ## ACTIVIDAD 16: Simulación de errores secuenciales en la red aleatoria
# Utilizando la función errores_secuenciales simula 99 errores en la red aleatoria. Almacena las listas de: cantidad de componentes conectados y las proporcion del componente gigante.

# %%
aleatoria_red_test=aleatoria_red.copy()
#num_cc_lista_aleatoria=[]
#prop_gc_lista_aleatoria=[]
(num_cc_lista_aleatoria,prop_gc_lista_aleatoria)=errores_secuenciales(aleatoria_red_test, 99)
# Out:
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:1.0
# La proporcion nodal entre Componente gigante y Red:0.975
# La proporcion nodal entre Componente gigante y Red:0.9487179487179487
# La proporcion nodal entre Componente gigante y Red:0.9473684210526315
# La proporcion nodal entre Componente gigante y Red:0.9459459459459459
# La proporcion nodal entre Componente gigante y Red:0.9444444444444444
# La proporcion nodal entre Componente gigante y Red:0.9428571428571428
# La proporcion nodal entre Componente gigante y Red:0.9411764705882353
# La proporcion nodal entre Componente gigante y Red:0.9393939393939394
# La proporcion nodal entre Componente gigante y Red:0.9375
# La proporcion nodal entre Componente gigante y Red:0.9354838709677419
# La proporcion nodal entre Componente gigante y Red:0.9333333333333333
# La proporcion nodal entre Componente gigante y Red:0.9310344827586207
# La proporcion nodal entre Componente gigante y Red:0.8928571428571429
# La proporcion nodal entre Componente gigante y Red:0.8888888888888888
# La proporcion nodal entre Componente gigante y Red:0.8846153846153846
# La proporcion nodal entre Componente gigante y Red:0.76
# La proporcion nodal entre Componente gigante y Red:0.7916666666666666
# La proporcion nodal entre Componente gigante y Red:0.6956521739130435
# La proporcion nodal entre Componente gigante y Red:0.6363636363636364
# La proporcion nodal entre Componente gigante y Red:0.6666666666666666
# La proporcion nodal entre Componente gigante y Red:0.7
# La proporcion nodal entre Componente gigante y Red:0.7368421052631579
# La proporcion nodal entre Componente gigante y Red:0.6111111111111112
# La proporcion nodal entre Componente gigante y Red:0.47058823529411764
# La proporcion nodal entre Componente gigante y Red:0.5
# La proporcion nodal entre Componente gigante y Red:0.5333333333333333
# La proporcion nodal entre Componente gigante y Red:0.5
# La proporcion nodal entre Componente gigante y Red:0.5384615384615384
# La proporcion nodal entre Componente gigante y Red:0.25
# La proporcion nodal entre Componente gigante y Red:0.2727272727272727
# La proporcion nodal entre Componente gigante y Red:0.3
# La proporcion nodal entre Componente gigante y Red:0.3333333333333333
# La proporcion nodal entre Componente gigante y Red:0.375
# La proporcion nodal entre Componente gigante y Red:0.42857142857142855
# La proporcion nodal entre Componente gigante y Red:0.5
# La proporcion nodal entre Componente gigante y Red:0.4
# La proporcion nodal entre Componente gigante y Red:0.25
# La proporcion nodal entre Componente gigante y Red:0.3333333333333333
# La proporcion nodal entre Componente gigante y Red:0.5
# La proporcion nodal entre Componente gigante y Red:1.0

# %% [markdown]
# ## ACTIVIDAD 17: Grafica de los componentes conectados vs. número de errores
# Utilizando la función grafica_funciones, grafique la cantidad de componentes conectados vs el número de errroes para las pruebas realizadas sobre la red de escala libre y la red aleatoria

# %%
titulo="Componentes Vs Numero de Errores"
f1_valores=num_cc_lista_free_scale
f2_valores=num_cc_lista_aleatoria
f1_leyenda="Escala Libre"
f2_leyenda="Red Aleatoria"
ejex_etiqueta="Errores"
ejey_etiqueta="Componentes"
grafica_funciones(titulo,f1_valores, f2_valores,f1_leyenda, f2_leyenda ,ejex_etiqueta, ejey_etiqueta)

# %% [markdown]
# ## ACTIVIDAD 18: Grafica de la proporción del componente gigante vs. número de errores
# Utilizando la función grafica_funciones, grafique la proporción del componente gigante vs el número de errrores para las pruebas realizadas sobre la red de escala libre y la red aleatoria

# %%
titulo="Proporcion Componente Gigante Vs Numero de Errores"
f1_valores=prop_gc_lista_free_scale
f2_valores=prop_gc_lista_aleatoria
f1_leyenda="Escala Libre"
f2_leyenda="Red Aleatoria"
ejex_etiqueta="Errores"
ejey_etiqueta="Proporcion Componente Gigante"
grafica_funciones(titulo,f1_valores, f2_valores,f1_leyenda, f2_leyenda ,ejex_etiqueta, ejey_etiqueta)

# %% [markdown]
# ## ACTIVIDAD 19 Simulación de ataques (por grado nodal) secuenciales
# Utilizando la función ataques_secuenciales simula 99 ataques en cada una de las red de escala libre. Recuerde pasar como parámetro de la función una copia de la red, así como guardar los resultados que devuelve la función.

# %%
free_scale_test2=free_scale.copy()
#num_cc_lista=[]
#prop_gc_lista=[]
(num_cc_lista_free_scale_secuencial,prop_gc_lista_free_scale_secuencial)=ataques_secuenciales(free_scale_test2, 99)
# Out:
# El grado más alto de la red es: 34
# el nodo con mayor grado es el nodo #:6
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 30
# el nodo con mayor grado es el nodo #:5
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 29
# el nodo con mayor grado es el nodo #:9
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 24
# el nodo con mayor grado es el nodo #:4
# el nodo con mayor grado es el nodo #:8
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 23
# el nodo con mayor grado es el nodo #:4
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 22
# el nodo con mayor grado es el nodo #:13
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 20
# el nodo con mayor grado es el nodo #:10
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 15
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:25
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 15
# el nodo con mayor grado es el nodo #:1
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 13
# el nodo con mayor grado es el nodo #:18
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 12
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:30
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 12
# el nodo con mayor grado es el nodo #:12
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 11
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:14
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:21
# el nodo con mayor grado es el nodo #:39
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 11
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:14
# el nodo con mayor grado es el nodo #:21
# La proporcion nodal entre Componente gigante y Red:0.9883720930232558
# El grado más alto de la red es: 11
# el nodo con mayor grado es el nodo #:14
# La proporcion nodal entre Componente gigante y Red:0.9882352941176471
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:32
# La proporcion nodal entre Componente gigante y Red:0.9880952380952381
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:17
# La proporcion nodal entre Componente gigante y Red:0.9879518072289156
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:2
# La proporcion nodal entre Componente gigante y Red:0.9878048780487805
# El grado más alto de la red es: 9
# el nodo con mayor grado es el nodo #:22
# La proporcion nodal entre Componente gigante y Red:0.9876543209876543
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:70
# La proporcion nodal entre Componente gigante y Red:0.9875
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# La proporcion nodal entre Componente gigante y Red:0.9873417721518988
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:42
# La proporcion nodal entre Componente gigante y Red:0.9743589743589743
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:24
# La proporcion nodal entre Componente gigante y Red:0.961038961038961
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:66
# La proporcion nodal entre Componente gigante y Red:0.9210526315789473
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:33
# La proporcion nodal entre Componente gigante y Red:0.92
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:31
# La proporcion nodal entre Componente gigante y Red:0.8783783783783784
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:23
# La proporcion nodal entre Componente gigante y Red:0.863013698630137
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:37
# La proporcion nodal entre Componente gigante y Red:0.8472222222222222
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:20
# La proporcion nodal entre Componente gigante y Red:0.8450704225352113
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:7
# La proporcion nodal entre Componente gigante y Red:0.8285714285714286
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:60
# el nodo con mayor grado es el nodo #:78
# La proporcion nodal entre Componente gigante y Red:0.8260869565217391
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:60
# La proporcion nodal entre Componente gigante y Red:0.6764705882352942
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:46
# La proporcion nodal entre Componente gigante y Red:0.6716417910447762
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:49
# el nodo con mayor grado es el nodo #:58
# el nodo con mayor grado es el nodo #:64
# el nodo con mayor grado es el nodo #:68
# el nodo con mayor grado es el nodo #:86
# La proporcion nodal entre Componente gigante y Red:0.6060606060606061
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:49
# el nodo con mayor grado es el nodo #:58
# el nodo con mayor grado es el nodo #:68
# La proporcion nodal entre Componente gigante y Red:0.4461538461538462
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:49
# La proporcion nodal entre Componente gigante y Red:0.34375
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:35
# La proporcion nodal entre Componente gigante y Red:0.23809523809523808
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:29
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:58
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:64
# el nodo con mayor grado es el nodo #:98
# La proporcion nodal entre Componente gigante y Red:0.24193548387096775
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:29
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:58
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:64
# La proporcion nodal entre Componente gigante y Red:0.21311475409836064
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:29
# el nodo con mayor grado es el nodo #:58
# La proporcion nodal entre Componente gigante y Red:0.15
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:29
# La proporcion nodal entre Componente gigante y Red:0.15254237288135594
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:19
# La proporcion nodal entre Componente gigante y Red:0.08620689655172414
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:76
# el nodo con mayor grado es el nodo #:84
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:87
# La proporcion nodal entre Componente gigante y Red:0.08771929824561403
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:76
# el nodo con mayor grado es el nodo #:84
# La proporcion nodal entre Componente gigante y Red:0.08928571428571429
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:76
# La proporcion nodal entre Componente gigante y Red:0.07272727272727272
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:73
# La proporcion nodal entre Componente gigante y Red:0.07407407407407407
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:72
# La proporcion nodal entre Componente gigante y Red:0.07547169811320754
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:41
# La proporcion nodal entre Componente gigante y Red:0.057692307692307696
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:38
# La proporcion nodal entre Componente gigante y Red:0.058823529411764705
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:36
# La proporcion nodal entre Componente gigante y Red:0.06
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:16
# La proporcion nodal entre Componente gigante y Red:0.061224489795918366
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:11
# La proporcion nodal entre Componente gigante y Red:0.041666666666666664
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:83
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:90
# el nodo con mayor grado es el nodo #:91
# el nodo con mayor grado es el nodo #:94
# el nodo con mayor grado es el nodo #:95
# La proporcion nodal entre Componente gigante y Red:0.0425531914893617
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:83
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:90
# el nodo con mayor grado es el nodo #:91
# La proporcion nodal entre Componente gigante y Red:0.043478260869565216
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:83
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:90
# La proporcion nodal entre Componente gigante y Red:0.044444444444444446
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:83
# La proporcion nodal entre Componente gigante y Red:0.045454545454545456
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# La proporcion nodal entre Componente gigante y Red:0.046511627906976744
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:74
# La proporcion nodal entre Componente gigante y Red:0.047619047619047616
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:65
# La proporcion nodal entre Componente gigante y Red:0.04878048780487805
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:63
# La proporcion nodal entre Componente gigante y Red:0.05
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:59
# La proporcion nodal entre Componente gigante y Red:0.05128205128205128
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:40
# La proporcion nodal entre Componente gigante y Red:0.02631578947368421
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# el nodo con mayor grado es el nodo #:93
# el nodo con mayor grado es el nodo #:94
# el nodo con mayor grado es el nodo #:96
# el nodo con mayor grado es el nodo #:97
# el nodo con mayor grado es el nodo #:99
# La proporcion nodal entre Componente gigante y Red:0.02702702702702703
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# el nodo con mayor grado es el nodo #:93
# el nodo con mayor grado es el nodo #:94
# el nodo con mayor grado es el nodo #:96
# el nodo con mayor grado es el nodo #:97
# La proporcion nodal entre Componente gigante y Red:0.027777777777777776
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# el nodo con mayor grado es el nodo #:93
# el nodo con mayor grado es el nodo #:94
# el nodo con mayor grado es el nodo #:96
# La proporcion nodal entre Componente gigante y Red:0.02857142857142857
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# el nodo con mayor grado es el nodo #:93
# el nodo con mayor grado es el nodo #:94
# La proporcion nodal entre Componente gigante y Red:0.029411764705882353
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# el nodo con mayor grado es el nodo #:93
# La proporcion nodal entre Componente gigante y Red:0.030303030303030304
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# el nodo con mayor grado es el nodo #:92
# La proporcion nodal entre Componente gigante y Red:0.03125
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:89
# La proporcion nodal entre Componente gigante y Red:0.03225806451612903
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# el nodo con mayor grado es el nodo #:88
# La proporcion nodal entre Componente gigante y Red:0.03333333333333333
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:85
# La proporcion nodal entre Componente gigante y Red:0.034482758620689655
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:81
# La proporcion nodal entre Componente gigante y Red:0.03571428571428571
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# el nodo con mayor grado es el nodo #:80
# La proporcion nodal entre Componente gigante y Red:0.037037037037037035
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:79
# La proporcion nodal entre Componente gigante y Red:0.038461538461538464
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:77
# La proporcion nodal entre Componente gigante y Red:0.04
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:75
# La proporcion nodal entre Componente gigante y Red:0.041666666666666664
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:71
# La proporcion nodal entre Componente gigante y Red:0.043478260869565216
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:69
# La proporcion nodal entre Componente gigante y Red:0.045454545454545456
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:67
# La proporcion nodal entre Componente gigante y Red:0.047619047619047616
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:62
# La proporcion nodal entre Componente gigante y Red:0.05
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:61
# La proporcion nodal entre Componente gigante y Red:0.05263157894736842
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:57
# La proporcion nodal entre Componente gigante y Red:0.05555555555555555
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:56
# La proporcion nodal entre Componente gigante y Red:0.058823529411764705
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:55
# La proporcion nodal entre Componente gigante y Red:0.0625
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# La proporcion nodal entre Componente gigante y Red:0.06666666666666667
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# La proporcion nodal entre Componente gigante y Red:0.07142857142857142
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# La proporcion nodal entre Componente gigante y Red:0.07692307692307693
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# La proporcion nodal entre Componente gigante y Red:0.08333333333333333
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# La proporcion nodal entre Componente gigante y Red:0.09090909090909091
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:48
# La proporcion nodal entre Componente gigante y Red:0.1
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:47
# La proporcion nodal entre Componente gigante y Red:0.1111111111111111
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:45
# La proporcion nodal entre Componente gigante y Red:0.125
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:43
# La proporcion nodal entre Componente gigante y Red:0.14285714285714285
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:34
# La proporcion nodal entre Componente gigante y Red:0.16666666666666666
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# La proporcion nodal entre Componente gigante y Red:0.2
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:27
# La proporcion nodal entre Componente gigante y Red:0.25
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:26
# La proporcion nodal entre Componente gigante y Red:0.3333333333333333
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:15
# La proporcion nodal entre Componente gigante y Red:0.5
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:3
# La proporcion nodal entre Componente gigante y Red:1.0

# %% [markdown]
# ## ACTIVIDAD 20 Simulación de ataques (por grado nodal) secuenciales
# Utilizando la función ataques_secuenciales simula 99 ataques en cada una de las red de escala libre. Recuerde pasar como parámetro de la función una copia de la red, así como guardar los resultados que devuelve la función.

# %%
aleatoria_red_test2=aleatoria_red.copy()
#num_cc_lista=[]
#prop_gc_lista=[]
#tupla_resultados=(num_cc_lista,prop_gc_lista)
(num_cc_lista_aleatoria_secuencial,prop_gc_lista_aleatoria_secuencial)=ataques_secuenciales(aleatoria_red_test2, 99)
# Out:
# El grado más alto de la red es: 18
# el nodo con mayor grado es el nodo #:64
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 17
# el nodo con mayor grado es el nodo #:25
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 16
# el nodo con mayor grado es el nodo #:14
# el nodo con mayor grado es el nodo #:58
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 16
# el nodo con mayor grado es el nodo #:14
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 15
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:95
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 14
# el nodo con mayor grado es el nodo #:18
# el nodo con mayor grado es el nodo #:29
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:81
# el nodo con mayor grado es el nodo #:89
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 14
# el nodo con mayor grado es el nodo #:18
# el nodo con mayor grado es el nodo #:29
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:81
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 14
# el nodo con mayor grado es el nodo #:18
# el nodo con mayor grado es el nodo #:29
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 14
# el nodo con mayor grado es el nodo #:18
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 13
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:90
# el nodo con mayor grado es el nodo #:97
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 13
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:67
# el nodo con mayor grado es el nodo #:90
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 13
# el nodo con mayor grado es el nodo #:33
# el nodo con mayor grado es el nodo #:67
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 13
# el nodo con mayor grado es el nodo #:33
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 12
# el nodo con mayor grado es el nodo #:0
# el nodo con mayor grado es el nodo #:8
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 12
# el nodo con mayor grado es el nodo #:0
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 11
# el nodo con mayor grado es el nodo #:77
# el nodo con mayor grado es el nodo #:83
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 11
# el nodo con mayor grado es el nodo #:77
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:4
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:39
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:80
# el nodo con mayor grado es el nodo #:87
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:4
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:39
# el nodo con mayor grado es el nodo #:47
# el nodo con mayor grado es el nodo #:80
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:4
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:39
# el nodo con mayor grado es el nodo #:47
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:4
# el nodo con mayor grado es el nodo #:39
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 10
# el nodo con mayor grado es el nodo #:4
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 9
# el nodo con mayor grado es el nodo #:30
# el nodo con mayor grado es el nodo #:91
# el nodo con mayor grado es el nodo #:92
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 9
# el nodo con mayor grado es el nodo #:30
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:91
# el nodo con mayor grado es el nodo #:96
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:74
# el nodo con mayor grado es el nodo #:82
# el nodo con mayor grado es el nodo #:91
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:72
# el nodo con mayor grado es el nodo #:74
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:6
# el nodo con mayor grado es el nodo #:72
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 8
# el nodo con mayor grado es el nodo #:6
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:68
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:76
# el nodo con mayor grado es el nodo #:82
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:68
# el nodo con mayor grado es el nodo #:69
# el nodo con mayor grado es el nodo #:76
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:68
# el nodo con mayor grado es el nodo #:69
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:41
# el nodo con mayor grado es el nodo #:68
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 7
# el nodo con mayor grado es el nodo #:41
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:71
# el nodo con mayor grado es el nodo #:85
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:56
# el nodo con mayor grado es el nodo #:71
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:45
# el nodo con mayor grado es el nodo #:56
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:23
# el nodo con mayor grado es el nodo #:45
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 6
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:23
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:32
# el nodo con mayor grado es el nodo #:49
# el nodo con mayor grado es el nodo #:93
# el nodo con mayor grado es el nodo #:99
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:32
# el nodo con mayor grado es el nodo #:49
# el nodo con mayor grado es el nodo #:93
# La proporcion nodal entre Componente gigante y Red:1.0
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:32
# el nodo con mayor grado es el nodo #:49
# La proporcion nodal entre Componente gigante y Red:0.9655172413793104
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# el nodo con mayor grado es el nodo #:32
# La proporcion nodal entre Componente gigante y Red:0.9122807017543859
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# el nodo con mayor grado es el nodo #:22
# La proporcion nodal entre Componente gigante y Red:0.9107142857142857
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:10
# el nodo con mayor grado es el nodo #:12
# La proporcion nodal entre Componente gigante y Red:0.9090909090909091
# El grado más alto de la red es: 5
# el nodo con mayor grado es el nodo #:10
# La proporcion nodal entre Componente gigante y Red:0.8703703703703703
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:21
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:43
# el nodo con mayor grado es el nodo #:65
# el nodo con mayor grado es el nodo #:79
# La proporcion nodal entre Componente gigante y Red:0.6981132075471698
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:21
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:43
# La proporcion nodal entre Componente gigante y Red:0.6538461538461539
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:2
# el nodo con mayor grado es el nodo #:21
# La proporcion nodal entre Componente gigante y Red:0.5490196078431373
# El grado más alto de la red es: 4
# el nodo con mayor grado es el nodo #:2
# La proporcion nodal entre Componente gigante y Red:0.52
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:62
# el nodo con mayor grado es el nodo #:65
# La proporcion nodal entre Componente gigante y Red:0.3673469387755102
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:19
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:62
# La proporcion nodal entre Componente gigante y Red:0.22916666666666666
# El grado más alto de la red es: 3
# el nodo con mayor grado es el nodo #:19
# La proporcion nodal entre Componente gigante y Red:0.23404255319148937
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:70
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:84
# el nodo con mayor grado es el nodo #:86
# el nodo con mayor grado es el nodo #:88
# el nodo con mayor grado es el nodo #:98
# La proporcion nodal entre Componente gigante y Red:0.17391304347826086
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:70
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:84
# el nodo con mayor grado es el nodo #:86
# el nodo con mayor grado es el nodo #:88
# La proporcion nodal entre Componente gigante y Red:0.17777777777777778
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:70
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:84
# el nodo con mayor grado es el nodo #:86
# La proporcion nodal entre Componente gigante y Red:0.18181818181818182
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:73
# el nodo con mayor grado es el nodo #:84
# La proporcion nodal entre Componente gigante y Red:0.11627906976744186
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:59
# el nodo con mayor grado es el nodo #:73
# La proporcion nodal entre Componente gigante y Red:0.11904761904761904
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:48
# el nodo con mayor grado es el nodo #:59
# La proporcion nodal entre Componente gigante y Red:0.12195121951219512
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# el nodo con mayor grado es el nodo #:48
# La proporcion nodal entre Componente gigante y Red:0.125
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# el nodo con mayor grado es el nodo #:35
# La proporcion nodal entre Componente gigante y Red:0.10256410256410256
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:27
# el nodo con mayor grado es el nodo #:28
# La proporcion nodal entre Componente gigante y Red:0.10526315789473684
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:27
# La proporcion nodal entre Componente gigante y Red:0.08108108108108109
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# el nodo con mayor grado es el nodo #:11
# La proporcion nodal entre Componente gigante y Red:0.08333333333333333
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# el nodo con mayor grado es el nodo #:9
# La proporcion nodal entre Componente gigante y Red:0.08571428571428572
# El grado más alto de la red es: 2
# el nodo con mayor grado es el nodo #:7
# La proporcion nodal entre Componente gigante y Red:0.058823529411764705
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:66
# el nodo con mayor grado es el nodo #:70
# el nodo con mayor grado es el nodo #:75
# el nodo con mayor grado es el nodo #:94
# La proporcion nodal entre Componente gigante y Red:0.06060606060606061
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:66
# el nodo con mayor grado es el nodo #:70
# el nodo con mayor grado es el nodo #:75
# La proporcion nodal entre Componente gigante y Red:0.0625
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:66
# el nodo con mayor grado es el nodo #:70
# La proporcion nodal entre Componente gigante y Red:0.06451612903225806
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:57
# el nodo con mayor grado es el nodo #:66
# La proporcion nodal entre Componente gigante y Red:0.06666666666666667
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# el nodo con mayor grado es el nodo #:57
# La proporcion nodal entre Componente gigante y Red:0.06896551724137931
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:55
# La proporcion nodal entre Componente gigante y Red:0.07142857142857142
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:26
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:36
# La proporcion nodal entre Componente gigante y Red:0.07407407407407407
# El grado más alto de la red es: 1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:26
# La proporcion nodal entre Componente gigante y Red:0.038461538461538464
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:60
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:63
# el nodo con mayor grado es el nodo #:78
# La proporcion nodal entre Componente gigante y Red:0.04
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:60
# el nodo con mayor grado es el nodo #:61
# el nodo con mayor grado es el nodo #:63
# La proporcion nodal entre Componente gigante y Red:0.041666666666666664
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:60
# el nodo con mayor grado es el nodo #:61
# La proporcion nodal entre Componente gigante y Red:0.043478260869565216
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# el nodo con mayor grado es el nodo #:60
# La proporcion nodal entre Componente gigante y Red:0.045454545454545456
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# el nodo con mayor grado es el nodo #:54
# La proporcion nodal entre Componente gigante y Red:0.047619047619047616
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# el nodo con mayor grado es el nodo #:53
# La proporcion nodal entre Componente gigante y Red:0.05
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# el nodo con mayor grado es el nodo #:52
# La proporcion nodal entre Componente gigante y Red:0.05263157894736842
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# el nodo con mayor grado es el nodo #:51
# La proporcion nodal entre Componente gigante y Red:0.05555555555555555
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# el nodo con mayor grado es el nodo #:50
# La proporcion nodal entre Componente gigante y Red:0.058823529411764705
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# el nodo con mayor grado es el nodo #:46
# La proporcion nodal entre Componente gigante y Red:0.0625
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# el nodo con mayor grado es el nodo #:44
# La proporcion nodal entre Componente gigante y Red:0.06666666666666667
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# el nodo con mayor grado es el nodo #:42
# La proporcion nodal entre Componente gigante y Red:0.07142857142857142
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# el nodo con mayor grado es el nodo #:40
# La proporcion nodal entre Componente gigante y Red:0.07692307692307693
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# el nodo con mayor grado es el nodo #:38
# La proporcion nodal entre Componente gigante y Red:0.08333333333333333
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# el nodo con mayor grado es el nodo #:37
# La proporcion nodal entre Componente gigante y Red:0.09090909090909091
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# el nodo con mayor grado es el nodo #:34
# La proporcion nodal entre Componente gigante y Red:0.1
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# el nodo con mayor grado es el nodo #:31
# La proporcion nodal entre Componente gigante y Red:0.1111111111111111
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# el nodo con mayor grado es el nodo #:24
# La proporcion nodal entre Componente gigante y Red:0.125
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# el nodo con mayor grado es el nodo #:20
# La proporcion nodal entre Componente gigante y Red:0.14285714285714285
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# el nodo con mayor grado es el nodo #:17
# La proporcion nodal entre Componente gigante y Red:0.16666666666666666
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# el nodo con mayor grado es el nodo #:16
# La proporcion nodal entre Componente gigante y Red:0.2
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# el nodo con mayor grado es el nodo #:15
# La proporcion nodal entre Componente gigante y Red:0.25
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# el nodo con mayor grado es el nodo #:13
# La proporcion nodal entre Componente gigante y Red:0.3333333333333333
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# el nodo con mayor grado es el nodo #:5
# La proporcion nodal entre Componente gigante y Red:0.5
# El grado más alto de la red es: 0
# el nodo con mayor grado es el nodo #:1
# el nodo con mayor grado es el nodo #:3
# La proporcion nodal entre Componente gigante y Red:1.0

# %% [markdown]
# ## ACTIVIDAD 21 Grafica de los componentes conectados vs. número de errores
# Utilizando la función grafica_funciones, grafique la proporción del componente gigante vs el número de errrores para las pruebas realizadas sobre la red de escala libre y la red aleatoria

# %%
titulo="Componentes Vs Numero de Errores Secuencial"
f1_valores=num_cc_lista_free_scale_secuencial
f2_valores=num_cc_lista_aleatoria_secuencial
f1_leyenda="Escala Libre"
f2_leyenda="Red Aleatoria"
ejex_etiqueta="Errores"
ejey_etiqueta="Componentes"
grafica_funciones(titulo,f1_valores, f2_valores,f1_leyenda, f2_leyenda ,ejex_etiqueta, ejey_etiqueta)

# %% [markdown]
# ## ACTIVIDAD 22: Grafica de la proporción del componente gigante vs. número de errores
# Utilizando la función grafica_funciones, grafique la proporción del componente gigante vs el número de errrores para las pruebas realizadas sobre la red de escala libre y la red aleatoria

# %%
titulo="Proporcion CG Vs Numero de Errores Secuencial"
f1_valores=prop_gc_lista_free_scale_secuencial
f2_valores=prop_gc_lista_aleatoria_secuencial
f1_leyenda="Escala Libre"
f2_leyenda="Red Aleatoria"
ejex_etiqueta="Errores"
ejey_etiqueta="Componentes"
grafica_funciones(titulo,f1_valores, f2_valores,f1_leyenda, f2_leyenda ,ejex_etiqueta, ejey_etiqueta)
